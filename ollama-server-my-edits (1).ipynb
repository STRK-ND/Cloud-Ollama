# %%
import os
import subprocess
import time
import socket
from pyngrok import ngrok
import getpass

# Change to working directory
os.chdir('/kaggle/working/')
print(os.getcwd())

def run(commands):
    """Execute shell commands and handle output"""
    for command in commands:
        with subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, bufsize=1) as sp:
            for line in sp.stdout:
                line = line.decode("utf-8", errors="replace")
                if "undefined reference" in line:
                    raise RuntimeError("Failed Processing.")
                print(line, flush=True, end="")

def wait_for_service(host, port, timeout=30):
    """Wait for a service to become available"""
    start_time = time.time()
    while time.time() - start_time < timeout:
        try:
            socket.create_connection((host, port), timeout=1)
            return True
        except socket.error:
            time.sleep(1)
    return False

def setup_environment():
    """Install required packages"""
    commands = [
        "sudo apt install lshw -y",
        "sudo apt install nginx -y",
        "pip install pyngrok ngrok --force"
    ]
    run(commands)

def install_ollama():
    """Install Ollama"""
    commands = ["curl -fsSL https://ollama.com/install.sh | sh"]
    run(commands)

def start_ollama_server():
    """Start the Ollama server with proper environment variables"""
    os.environ['OLLAMA_HOST'] = "0.0.0.0"
    os.environ['OLLAMA_ORIGINS'] = "*"

    try:
        print("Starting Ollama server...")
        server_process = subprocess.Popen(
            "/usr/local/bin/ollama serve",
            shell=True,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE
        )
        
        # Wait for server to start
        if not wait_for_service('localhost', 11434):
            raise Exception("Ollama server failed to start")
        
        print("Ollama server started successfully")
        return server_process
        
    except Exception as e:
        print(f"Error starting Ollama server: {str(e)}")
        raise

def setup_nginx():
    """Configure and start nginx"""
    nginx_config = '''
server {
    listen 80;
    server_name *.ngrok-free.app;

    location / {
        proxy_pass http://localhost:11434;
        proxy_http_version 1.1;
        proxy_set_header Upgrade $http_upgrade;
        proxy_set_header Connection 'upgrade';
        proxy_set_header Host $host;
        proxy_cache_bypass $http_upgrade;
    }
}
'''
    
    # Write nginx configuration
    with open('/etc/nginx/conf.d/ollamasvc.conf', 'w') as f:
        f.write(nginx_config)
    
    # Stop nginx if running
    subprocess.run(["sudo", "/etc/init.d/nginx", "stop"])
    time.sleep(2)
    
    # Start nginx
    subprocess.run(["sudo", "/etc/init.d/nginx", "start"])
    time.sleep(2)
    
    # Verify nginx is running
    if not wait_for_service('localhost', 80):
        raise Exception("Nginx failed to start")

def setup_models():
    """Setup Ollama models"""
    # Write Modelfile
    with open('/kaggle/working/Modelfile3', 'w') as f:
        f.write('''FROM llama3.1
PARAMETER num_ctx 32768''')
    
    commands = [
        "ollama create -f /kaggle/working/Modelfile3 llama3.1-extra-ctx"
        #"ollama pull qwen2.5:14b"
    ]
    run(commands)
    
    # List available models
    run(["ollama list"])

def setup_ngrok():
    """Configure and start ngrok"""
    ngrok_token = getpass.getpass('Enter your NGrok access token and press enter: ')
    
    # Set ngrok auth token
    run([f"ngrok authtoken {ngrok_token}"])
    print("NGROK_TOKEN Auth Token has been set.")
    
    # Create ngrok tunnel
    listener = ngrok.connect(
        addr="localhost:80",
        metadata="Ollama API Service",
    )
    print(f"Ngrok tunnel established: {listener}")
    return listener

def main():
    try:
        # Step 1: Setup environment
        print("Setting up environment...")
        setup_environment()
        
        # Step 2: Install Ollama
        print("Installing Ollama...")
        install_ollama()
        
        # Step 3: Start Ollama server
        print("Starting Ollama server...")
        ollama_process = start_ollama_server()
        
        # Step 4: Setup nginx
        print("Setting up nginx...")
        setup_nginx()
        
        # Step 5: Setup models
        print("Setting up models...")
        setup_models()
        
        # Step 6: Setup ngrok
        print("Setting up ngrok...")
        listener = setup_ngrok()
        
        print("\nSetup completed successfully!")
        print(f"Your Ollama API is now accessible at: {listener.public_url}")
        
        # Keep the script running
        try:
            while True:
                time.sleep(1)
        except KeyboardInterrupt:
            print("Shutting down...")
            ngrok.disconnect(listener.public_url)
            ollama_process.terminate()
            subprocess.run(["sudo", "/etc/init.d/nginx", "stop"])
            
    except Exception as e:
        print(f"An error occurred: {str(e)}")
        raise

if __name__ == "__main__":
    main()
# Out:
# /kaggle/working
# Setting up environment...
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# Reading package lists...
# Building dependency tree...
# Reading state information...
# lshw is already the newest version (02.19.git.2021.06.19.996aaad9c7-2build1).
# 0 upgraded, 0 newly installed, 0 to remove and 132 not upgraded.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# Reading package lists...
# Building dependency tree...
# Reading state information...
# nginx is already the newest version (1.18.0-6ubuntu14.5).
# 0 upgraded, 0 newly installed, 0 to remove and 132 not upgraded.
# Collecting pyngrok
#   Using cached pyngrok-7.2.3-py3-none-any.whl.metadata (8.7 kB)
# Collecting ngrok
#   Using cached ngrok-1.4.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting PyYAML>=5.1 (from pyngrok)
#   Using cached PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Using cached pyngrok-7.2.3-py3-none-any.whl (23 kB)
# Using cached ngrok-1.4.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Using cached PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
# Installing collected packages: PyYAML, ngrok, pyngrok
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
#   Attempting uninstall: ngrok
#     Found existing installation: ngrok 1.4.0
#     Uninstalling ngrok-1.4.0:
#       Successfully uninstalled ngrok-1.4.0
#   Attempting uninstall: pyngrok
#     Found existing installation: pyngrok 7.2.3
#     Uninstalling pyngrok-7.2.3:
#       Successfully uninstalled pyngrok-7.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# distributed 2024.8.0 requires dask==2024.8.0, but you have dask 2024.12.1 which is incompatible.
# Successfully installed PyYAML-6.0.2 ngrok-1.4.0 pyngrok-7.2.3
# Installing Ollama...
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ############################################################################################# 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# >>> NVIDIA GPU installed.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# Starting Ollama server...
# Starting Ollama server...
# Ollama server started successfully
# Setting up nginx...
# Setting up models...
# transferring model data
# /usr/lib/python3.10/subprocess.py:961: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# pulling manifest ⠋ transferring model data
# pulling manifest ⠙ transferring model data
# pulling manifest ⠹ transferring model data
# pulling manifest ⠸ transferring model data
# pulling manifest ⠼ transferring model data
# pulling manifest ⠴ transferring model data
# pulling manifest
# pulling 667b0c1932bc...   0% ▕                ▏    0 B/4.9 GB                  transferring model data
# pulling manifest
# pulling 667b0c1932bc...   0% ▕                ▏    0 B/4.9 GB                  transferring model data
# pulling manifest
# pulling 667b0c1932bc...   0% ▕                ▏    0 B/4.9 GB                  transferring model data
# pulling manifest
# pulling 667b0c1932bc...   1% ▕                ▏  24 MB/4.9 GB                  transferring model data
# pulling manifest
# pulling 667b0c1932bc...   1% ▕                ▏  33 MB/4.9 GB                  transferring model data
# pulling manifest
# pulling 667b0c1932bc...   2% ▕                ▏ 101 MB/4.9 GB                  transferring model data
# pulling manifest
# pulling 667b0c1932bc...   4% ▕                ▏ 175 MB/4.9 GB                  transferring model data
# pulling manifest
# pulling 667b0c1932bc...   4% ▕                ▏ 214 MB/4.9 GB                  transferring model data
# pulling manifest
# pulling 667b0c1932bc...   6% ▕                ▏ 275 MB/4.9 GB                  transferring model data
# pulling manifest
# pulling 667b0c1932bc...   7% ▕█               ▏ 347 MB/4.9 GB                  transferring model data
# pulling manifest
# pulling 667b0c1932bc...   8% ▕█               ▏ 380 MB/4.9 GB                  transferring model data
# pulling manifest
# pulling 667b0c1932bc...   9% ▕█               ▏ 443 MB/4.9 GB  409 MB/s     10stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  10% ▕█               ▏ 516 MB/4.9 GB  409 MB/s     10stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  11% ▕█               ▏ 549 MB/4.9 GB  409 MB/s     10stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  13% ▕██              ▏ 621 MB/4.9 GB  409 MB/s     10stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  14% ▕██              ▏ 692 MB/4.9 GB  409 MB/s     10stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  15% ▕██              ▏ 726 MB/4.9 GB  409 MB/s     10stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  16% ▕██              ▏ 806 MB/4.9 GB  409 MB/s     10stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  18% ▕██              ▏ 887 MB/4.9 GB  409 MB/s      9stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  19% ▕███             ▏ 923 MB/4.9 GB  409 MB/s      9stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  20% ▕███             ▏ 1.0 GB/4.9 GB  409 MB/s      9stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  22% ▕███             ▏ 1.1 GB/4.9 GB  517 MB/s      7stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  22% ▕███             ▏ 1.1 GB/4.9 GB  517 MB/s      7stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  24% ▕███             ▏ 1.2 GB/4.9 GB  517 MB/s      7stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  25% ▕████            ▏ 1.3 GB/4.9 GB  517 MB/s      7stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  26% ▕████            ▏ 1.3 GB/4.9 GB  517 MB/s      7stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  28% ▕████            ▏ 1.4 GB/4.9 GB  517 MB/s      6stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  29% ▕████            ▏ 1.4 GB/4.9 GB  517 MB/s      6stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  30% ▕████            ▏ 1.5 GB/4.9 GB  517 MB/s      6stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  31% ▕████            ▏ 1.5 GB/4.9 GB  517 MB/s      6stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  33% ▕█████           ▏ 1.6 GB/4.9 GB  517 MB/s      6stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  33% ▕█████           ▏ 1.6 GB/4.9 GB  547 MB/s      5stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  35% ▕█████           ▏ 1.7 GB/4.9 GB  547 MB/s      5stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  36% ▕█████           ▏ 1.8 GB/4.9 GB  547 MB/s      5stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  37% ▕█████           ▏ 1.8 GB/4.9 GB  547 MB/s      5stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  39% ▕██████          ▏ 1.9 GB/4.9 GB  547 MB/s      5stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  40% ▕██████          ▏ 2.0 GB/4.9 GB  547 MB/s      5stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  41% ▕██████          ▏ 2.0 GB/4.9 GB  547 MB/s      5stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  42% ▕██████          ▏ 2.1 GB/4.9 GB  547 MB/s      5stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  44% ▕██████          ▏ 2.2 GB/4.9 GB  547 MB/s      5stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  44% ▕███████         ▏ 2.2 GB/4.9 GB  547 MB/s      4stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  46% ▕███████         ▏ 2.3 GB/4.9 GB  564 MB/s      4stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  47% ▕███████         ▏ 2.3 GB/4.9 GB  564 MB/s      4stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  48% ▕███████         ▏ 2.4 GB/4.9 GB  564 MB/s      4stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  50% ▕███████         ▏ 2.4 GB/4.9 GB  564 MB/s      4stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  51% ▕████████        ▏ 2.5 GB/4.9 GB  564 MB/s      4stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  52% ▕████████        ▏ 2.6 GB/4.9 GB  564 MB/s      4stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  54% ▕████████        ▏ 2.6 GB/4.9 GB  564 MB/s      4stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  55% ▕████████        ▏ 2.7 GB/4.9 GB  564 MB/s      3stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  56% ▕████████        ▏ 2.7 GB/4.9 GB  564 MB/s      3stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  57% ▕█████████       ▏ 2.8 GB/4.9 GB  564 MB/s      3stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  58% ▕█████████       ▏ 2.9 GB/4.9 GB  573 MB/s      3stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  59% ▕█████████       ▏ 2.9 GB/4.9 GB  573 MB/s      3stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  60% ▕█████████       ▏ 3.0 GB/4.9 GB  573 MB/s      3stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  61% ▕█████████       ▏ 3.0 GB/4.9 GB  573 MB/s      3stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  62% ▕█████████       ▏ 3.0 GB/4.9 GB  573 MB/s      3stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  63% ▕██████████      ▏ 3.1 GB/4.9 GB  573 MB/s      3stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  64% ▕██████████      ▏ 3.2 GB/4.9 GB  573 MB/s      3stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  65% ▕██████████      ▏ 3.2 GB/4.9 GB  573 MB/s      3stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  66% ▕██████████      ▏ 3.3 GB/4.9 GB  573 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  67% ▕██████████      ▏ 3.3 GB/4.9 GB  573 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  68% ▕██████████      ▏ 3.4 GB/4.9 GB  573 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  69% ▕███████████     ▏ 3.4 GB/4.9 GB  563 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  71% ▕███████████     ▏ 3.5 GB/4.9 GB  563 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  71% ▕███████████     ▏ 3.5 GB/4.9 GB  563 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  72% ▕███████████     ▏ 3.6 GB/4.9 GB  563 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  74% ▕███████████     ▏ 3.6 GB/4.9 GB  563 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  74% ▕███████████     ▏ 3.7 GB/4.9 GB  563 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  75% ▕████████████    ▏ 3.7 GB/4.9 GB  563 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  77% ▕████████████    ▏ 3.8 GB/4.9 GB  563 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  77% ▕████████████    ▏ 3.8 GB/4.9 GB  563 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  79% ▕████████████    ▏ 3.9 GB/4.9 GB  563 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  80% ▕████████████    ▏ 3.9 GB/4.9 GB  556 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  80% ▕████████████    ▏ 4.0 GB/4.9 GB  556 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  82% ▕█████████████   ▏ 4.0 GB/4.9 GB  556 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  83% ▕█████████████   ▏ 4.1 GB/4.9 GB  556 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  83% ▕█████████████   ▏ 4.1 GB/4.9 GB  556 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  85% ▕█████████████   ▏ 4.2 GB/4.9 GB  556 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  86% ▕█████████████   ▏ 4.2 GB/4.9 GB  556 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  87% ▕█████████████   ▏ 4.3 GB/4.9 GB  556 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  88% ▕██████████████  ▏ 4.3 GB/4.9 GB  556 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  89% ▕██████████████  ▏ 4.4 GB/4.9 GB  556 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  90% ▕██████████████  ▏ 4.4 GB/4.9 GB  551 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  91% ▕██████████████  ▏ 4.5 GB/4.9 GB  551 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  92% ▕██████████████  ▏ 4.5 GB/4.9 GB  551 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  93% ▕██████████████  ▏ 4.6 GB/4.9 GB  551 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  93% ▕██████████████  ▏ 4.6 GB/4.9 GB  551 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  94% ▕███████████████ ▏ 4.6 GB/4.9 GB  551 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  94% ▕███████████████ ▏ 4.6 GB/4.9 GB  551 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  94% ▕███████████████ ▏ 4.6 GB/4.9 GB  551 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  94% ▕███████████████ ▏ 4.6 GB/4.9 GB  551 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  94% ▕███████████████ ▏ 4.6 GB/4.9 GB  551 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  516 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  516 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  516 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  516 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  516 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  516 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  516 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  516 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  516 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  516 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  472 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  472 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  472 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  472 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  472 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  472 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  472 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  472 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  472 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  472 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  472 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  404 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  404 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  404 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  404 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  404 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  404 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  404 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  404 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  404 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  404 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  337 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  337 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  337 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  337 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  337 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  337 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  337 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  337 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  337 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  337 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  268 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  268 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  268 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  268 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  268 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  268 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  268 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  268 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  268 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  268 MB/s      0stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  201 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  201 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  201 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  201 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  201 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  201 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  201 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  201 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  201 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  201 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  145 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  145 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  145 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  145 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  145 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  145 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  145 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  145 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  145 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  145 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB  145 MB/s      1stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   88 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   88 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   88 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   88 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   88 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   88 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   88 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   88 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   88 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   88 MB/s      2stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   31 MB/s      7stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   31 MB/s      7stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   31 MB/s      7stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   31 MB/s      7stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   31 MB/s      7stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   31 MB/s      7stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   31 MB/s      7stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   31 MB/s      7stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  95% ▕███████████████ ▏ 4.7 GB/4.9 GB   31 MB/s      7stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB   31 MB/s      7stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  5.4 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  5.4 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  5.4 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  5.4 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  5.4 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  5.4 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  5.4 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  5.4 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  5.4 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  5.4 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     48stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     48stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     48stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.3 MB/s     48stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.3 MB/s     48stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.3 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.3 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.3 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.3 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.3 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.3 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.3 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.3 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     48stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     48stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     48stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     48stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     48stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     48stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     48stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     47stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     46stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     46stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     46stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     46stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     46stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     44stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     44stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     44stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     44stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     42stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     42stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.5 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.4 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     42stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     42stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     42stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     42stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     42stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     42stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.2 MB/s     41stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.0 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.0 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.0 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.0 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.0 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.0 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.0 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  96% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.0 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.0 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.7 GB/4.9 GB  4.0 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.7 GB/4.9 GB  3.9 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.7 GB/4.9 GB  3.9 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     43stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     42stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     42stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.1 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.1 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.1 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.1 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.1 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.1 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.1 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.1 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.1 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.1 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     39stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     39stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     39stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     40stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     39stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     39stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     39stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  3.9 MB/s     39stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     38stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     38stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     38stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     38stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     37stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     37stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     37stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     37stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     37stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.0 MB/s     37stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.2 MB/s     34stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.2 MB/s     34stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.2 MB/s     34stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.2 MB/s     34stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.2 MB/s     34stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.2 MB/s     34stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.2 MB/s     34stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.2 MB/s     34stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.2 MB/s     34stransferring model data
# pulling manifest
# pulling 667b0c1932bc...  97% ▕███████████████ ▏ 4.8 GB/4.9 GB  4.2 MB/s     34stransferring model data
# ...
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠏ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠋ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠙ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠹ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠸ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠼ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠴ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠦ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠧ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠇ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠏ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠋ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠙ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠹ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠸ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠼ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠴ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠦ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠧ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠇ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠏ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠋ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠙ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠹ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠸ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠼ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠴ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠦ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest ⠧ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest
# writing manifest
# success ⠋ transferring model data
# pulling manifest
# pulling 667b0c1932bc... 100% ▕████████████████▏ 4.9 GB
# pulling 948af2743fc7... 100% ▕████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4... 100% ▕████████████████▏  12 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 455f34728c9b... 100% ▕████████████████▏  487 B
# verifying sha256 digest
# writing manifest
# success
# using existing layer sha256:667b0c1932bc6ffc593ed1d03f895bf2dc8dc6df21db3042284a6f4416b06a29
# using existing layer sha256:948af2743fc78a328dcb3b0f5a31b3d75f415840fdb699e8b1235978392ecf85
# using existing layer sha256:0ba8f0e314b4264dfd19df045cde9d4c394a52474bf92ed6a3de22a4ca31a177
# using existing layer sha256:9297317326db356372cab36abaf8c0da99f85c4b4f30e788b3f1a1bcbba30685
# creating new layer sha256:427964bb9172cc8b3e031479416112a185ed6adddc97d9982b7aac878130cf76
# writing manifest
# success
# NAME                         ID              SIZE      MODIFIED
# llama3.1-extra-ctx:latest    a04878b73b00    4.9 GB    Less than a second ago
# llama3.1:latest              46e0c10c039e    4.9 GB    Less than a second ago
# llama3.2-extra-ctx:latest    5f8672eff6ca    2.0 GB    4 minutes ago
# qwen2.5:14b                  7cdf5a0187d5    9.0 GB    4 minutes ago
# llama3.2:latest              a80c4f17acd5    2.0 GB    14 minutes ago
# Setting up ngrok...
# Enter your NGrok access token and press enter:  ········
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# NGROK_TOKEN Auth Token has been set.
# Ngrok tunnel established: NgrokTunnel: "https://f6f8-104-154-160-249.ngrok-free.app" -> "http://localhost:80"
#
# Setup completed successfully!
# Your Ollama API is now accessible at: https://f6f8-104-154-160-249.ngrok-free.app
